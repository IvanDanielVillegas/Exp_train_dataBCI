# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install mne

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal
import math
import mne
# %matplotlib inline

# %%
epochs = mne.read_epochs('/content/drive/MyDrive/BCI/BCICompetition/data/Train_set/oddball_train_epo.fif')
# Out:
# Reading /content/drive/MyDrive/BCI/BCICompetition/data/Train_set/oddball_train_epo.fif ...
#     Found the data of interest:
#         t =    -300.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 3420 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
epochs["P300"].plot_image(picks=[10])
# Out:
# Not setting metadata
# 570 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 640x480 with 4 Axes>]

# %%
epochs["NoP300"].plot_image(picks=[10])
# Out:
# Not setting metadata
# 2850 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 640x480 with 4 Axes>]

# %%
target = epochs["P300"].average()
target
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <Evoked | 'P300' (average, N=570), -0.3 – 0.7 s, baseline -0.3 – 0 s, 64 ch, ~215 kB>

# %%
standart = epochs["NoP300"].average()
standart
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <Evoked | 'NoP300' (average, N=2850), -0.3 – 0.7 s, baseline -0.3 – 0 s, 64 ch, ~215 kB>

# %%
target.plot_topomap()
# Out:
# <MNEFigure size 750x220 with 5 Axes>
# <MNEFigure size 750x220 with 5 Axes>

# %%
standart.plot_topomap()
# Out:
# <MNEFigure size 750x220 with 5 Axes>
# <MNEFigure size 750x220 with 5 Axes>

# %%
target.plot(time_unit='s',exclude=[])

# %%
standart.plot(time_unit='s',exclude=[])

# %%
fig=target.plot_joint()
fig.savefig('target_signal_avg_Competition.png')
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).

# %%
fig=standart.plot_joint()
fig.savefig('standart_signal_avg_Competition.png')
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).

# %%
mne.viz.plot_compare_evokeds({"standart":standart,
                              "target":target},picks=[10])
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
fig = target.plot_sensors(show_names=True)
fig.savefig("ElectrodosBCICompetition.png", format="png")

# %%
target.plot_topo()

# %%
standart.plot_topo()

# %%
epochs = mne.read_epochs('/content/drive/MyDrive/BCI/BCICompetition/data/Train_set/elect_mean_epo.fif')
# Out:
# Reading /content/drive/MyDrive/BCI/BCICompetition/data/Train_set/elect_mean_epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    -304.00 ...     696.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1140 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
epochs['1'].plot_image(picks=['C'])#P300
epochs['0'].plot_image(picks=['C'])#NoP300
# Out:
# Not setting metadata
# 570 matching events found
# No baseline correction applied
# 0 projection items activated
# <ipython-input-95-eb2e5eb7b421>:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs['1'].plot_image(picks=['C'])#P300
# Not setting metadata
# 570 matching events found
# No baseline correction applied
# 0 projection items activated
# <ipython-input-95-eb2e5eb7b421>:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs['0'].plot_image(picks=['C'])#NoP300
# [<Figure size 640x480 with 3 Axes>]

# %%
target = epochs["1"].average()
target
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <Evoked | '1' (average, N=570), -0.304 – 0.696 s, baseline off, 3 ch, ~12 kB>

# %%
standart = epochs["0"].average()
standart
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <Evoked | '0' (average, N=570), -0.304 – 0.696 s, baseline off, 3 ch, ~12 kB>

# %%
fig = target.plot(time_unit='s',exclude=[])

# %%
fig = standart.plot(time_unit='s',exclude=[])

# %%
mne.viz.plot_compare_evokeds({"standart":standart,
                              "target":target},picks=['C'])
# Out:
# <ipython-input-99-1e01016429c6>:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds({"standart":standart,
# [<Figure size 800x600 with 1 Axes>]
